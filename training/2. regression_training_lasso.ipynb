# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from openpyxl) (2.0.0)

# %%
import numpy as np
import pandas as pd
from dateutil.relativedelta import relativedelta
import os
import glob
import boto3
import s3fs
import tarfile
import joblib
import tempfile
from config_module import Config
config = Config()
# **IMPORTANT**: Have to do this line *before* importing tensorflow
os.environ['PYTHONHASHSEED'] = str(2)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
from time import gmtime, strftime
import sagemaker
from sagemaker.sklearn import SKLearn
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sklearn.preprocessing import MinMaxScaler
from pickle import dump, load
import warnings
import json
import random

# Set seed for reproducibility
np.random.seed(42)
pd.options.mode.chained_assignment = None

# Import modules
import itertools
import math
import pickle
from datetime import datetime, timezone, timedelta

from sklearn.linear_model import Lasso, LinearRegression, Ridge
from sklearn.metrics import (mean_absolute_error, mean_absolute_percentage_error,
                             mean_squared_error)
from sklearn.model_selection import (GridSearchCV, TimeSeriesSplit,
                                     train_test_split)
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings('ignore')
random.seed(12)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
start_time = datetime.now()

# %%
# training_date = datetime.now().strftime('%Y%m%d')

# s3_json_path = "s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/input-data/"
# json_file_path = 'config.json'
# # Read the existing JSON file
# with open(json_file_path, 'r') as file:
#     data = json.load(file)

# # with open(s3_json_path, 'r') as file:
# #     s3_data = json.load(file)

# # Update the model_training_date key with the new date
# data['model_training_date'] = training_date
# # s3_data['model_training_date'] = training_date

# # Write the updated JSON back to the file
# with open(json_file_path, 'w') as file:
#     json.dump(data, file, indent=4)


# # Write the updated JSON back to the S3 folder
# # with open(s3_json_path, 'w') as file:
# #     json.dump(s3_data, file, indent=4)

# %%
def read_file(file_path):
    file_extension = os.path.splitext(file_path)[1].lower()
    
    if file_extension == '.xlsx':
        # Read Excel file
        data = pd.read_excel(file_path)
    elif file_extension == '.csv':
        # Read CSV file
        data = pd.read_csv(file_path)
    elif file_extension == '.txt':
        # Read TXT file
        data = pd.read_csv(file_path)
    else:
        raise ValueError("Unsupported file format: {}".format(file_extension))
    
    return data

# %%
def get_latest_file(folder_path, file_prefix):
    # Construct the search pattern for the CSV files with the given prefix
    search_pattern = os.path.join(folder_path, f"{file_prefix}*")
    
    
    # Get the list of matching files
    csv_files = glob.glob(search_pattern)
    
    
    if not csv_files:
        print("No CSV files found.")
        return None
    
    # Extract the datetime part and convert it to a datetime object
    csv_files_with_dates = []
    for file in csv_files:
        try:
            # Extract the datetime stamp from the file name
            datetime_stamp = file[len(folder_path) + len(file_prefix) + 1:-5]
            file_datetime = datetime.strptime(datetime_stamp, "%y%m%d_%H%M%S")
            csv_files_with_dates.append((file, file_datetime))
        except ValueError:
            print(f"Could not parse date from file name: {file}")
    
    if not csv_files_with_dates:
        print("No valid CSV files found.")
        return None
    
    # Sort the files by datetime in descending order and get the latest one
    latest_file = max(csv_files_with_dates, key=lambda x: x[1])[0]
    
    return latest_file

# %%
def get_latest_s3_file(bucket_name, path_prefix, file_prefix):
    s3 = boto3.client('s3')
    
    # List all objects under the given path_prefix
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=path_prefix)
    
    if 'Contents' not in response:
        print("No files found.")
        return None
    
    # Filter objects that start with the specific file path_prefix
    filtered_files = [
        obj for obj in response['Contents'] 
        if obj['Key'].startswith(f"{path_prefix}{file_prefix}")
    ]
    
    if not filtered_files:
        print("No files found with the specific path_prefix.")
        return None
    
    # Extract the date from each file name and store along with the key
    files_with_dates = []
    for obj in filtered_files:
        key = obj['Key']
        # Assuming the date is at the end of the filename after the last underscore
        try:
            # Get the base name without directory path
            base_name = os.path.basename(key)
            name_without_extension = os.path.splitext(base_name)[0]
            date_str = name_without_extension.split('_')[-1]  # Get the date string part
            file_date = datetime.strptime(date_str, "%Y-%m-%d")  # Parse date
            files_with_dates.append((key, file_date))
        except ValueError as e:
            print(f"Error parsing date from file name {key}: {e}")

    if not files_with_dates:
        print("No valid files with dates found.")
        return None

    # Find the file with the latest date
    latest_file_key, latest_date = max(files_with_dates, key=lambda x: x[1])
    
    return latest_file_key

# %%
def create_lagged_features(data, lag, pred_win):
    """
    This function creates lagged features for the given time series data.
    
    Parameters:
    data (pd.Series): The input time series data.
    lag (int): The number of lagged periods to create.
    pred_win (int): The prediction window size.
    
    Returns:
    pd.DataFrame: A DataFrame containing the lagged features.
    """
    
    # Initialize an empty DataFrame with the same index as the input data
    lagged_data = pd.DataFrame(index=data.index)
    
    # Create lagged features by shifting the data by (lag + pred_win - 1) periods
    for i in range(1, lag + 1):
        lagged_data[f'lag_{i}'] = data.shift(i + (pred_win - 1))
    
    return lagged_data

# Function to forecast future values using a model
def forecast(df, model, n_periods=3):
    """
    This function forecasts future values using the provided model.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame containing the time series data.
    model (object): The trained model to be used for forecasting.
    n_periods (int): The number of periods to forecast.
    
    Returns:
    list: A list of forecasted values.
    """
    # Get the last 'n_periods' values from the 'Total_qty_per_month' column
    last_values = df['Total_qty_per_month'][-3:].values
    
    # Initialize an empty list to store the forecasted values
    forecasts = []
    
    # Generate forecasts for the specified number of periods
    for _ in range(n_periods):
        # Extract the features for the model (last 'lag' values)
        # features = last_values[-lag:]
        features = last_values[-3:]
        
        # Predict the next value using the model
        pred = model.predict(features.reshape(1, -1))[0]
        
        # Append the predicted value to the forecasts list
        forecasts.append(pred)
        
        # Update the last values by appending the predicted value and removing the oldest value
        last_values = np.append(last_values, pred)[1:]
    
    return forecasts

# %%
bucket = config.get_value('bucket')
prefix_output_file = config.get_value('prefix_cleaned_training_file_path')
file_name_prefix = config.get_value('cleaned_training_filename_prefix')
file_path = get_latest_s3_file(bucket,prefix_output_file,file_name_prefix)
print(file_path)
final_data = pd.read_excel('s3://'+f'{bucket}/{file_path}')
parts_list = final_data['part_number'].unique().tolist()
# Out:
# persist-bo/persist-bo-demand-forecast/cleaned-training-data/clean_data_imputed_2024-11-06.xlsx

# %%
len(parts_list)
# Out:
# 6525

# %%
training_end_date = (pd.to_datetime(final_data['period']).max() + relativedelta(months=-3)).strftime('%Y-%m-%d')

# %%
def get_consecutive_months(start_date, n_months=3):
    """
    Generate a list of consecutive month start dates.

    Args:
    - start_date (str): Starting date in 'YYYY-MM-DD' format.
    - n_months (int): Number of consecutive months to generate.

    Returns:
    - list: List of consecutive month start dates in 'YYYY-MM-DD' format.
    """
    start_date = pd.to_datetime(start_date)
    month_list = [(start_date + pd.DateOffset(months=i)).strftime('%Y-%m-%d') for i in range(1, n_months + 1)]
    return month_list

# %%
print(datetime.now())
# Out:
# 2024-11-06 13:04:28.774247

# %%
# Lasso lag 1
#final_lasso_lag1
def lasso_lag1_func(clean_data, s3_bucketname, pickle_path_lasso_lag1, last_training_date):
    df1=clean_data[:]
    df1=df1[['part_number','period','Total_qty_per_month']]
    df1['period'] = pd.to_datetime(df1['period'])
    df1=df1.sort_values('period')
    s3_client = boto3.client('s3')
    fs = s3fs.S3FileSystem()
    #create a model folder for saving pickle with a changed name
    model_folder = pickle_path_lasso_lag1[:]
    last_test_date = (pd.to_datetime(last_training_date) + relativedelta(months=3)).strftime('%Y-%m-%d')
    future_dates = get_consecutive_months(last_test_date)
    final_metric_lag1_lasso=pd.DataFrame()
    for i in df1['part_number'].unique():
        try:
            print(i)
            data= df1[df1['part_number']==i]            
            data.drop('part_number',axis=1,inplace=True)
            data['month'] = data['period'].dt.month
            
            # Step 1: Create and combine lagged features with original data
            lag = 3
            pred_win=1 #prediction window needs to be updated      
            lagged_data = create_lagged_features(data['Total_qty_per_month'], lag,pred_win)
            data_with_lags = pd.concat([data, lagged_data], axis=1)
            data_with_lags.fillna(data_with_lags.median(), inplace=True)
            
            # Step 2: Split the Data to create training and testing datasets
            train_size = len(data_with_lags)-3
            train_data = data_with_lags.iloc[:train_size]
            test_data = data_with_lags.iloc[train_size:]
            X_train_scaled = train_data.drop(['period', 'month','Total_qty_per_month'], axis=1)
            X_test_scaled= X_train_scaled[-3:]
            y_train = train_data['Total_qty_per_month']
            #y_test = test_data[:]
            
            # Step 3: Fit the Ridge Regression Model
            lasso = Lasso(alpha=1,random_state=42)  # Adjust alpha as needed
            lasso.fit(X_train_scaled, y_train)
            ################
            print("path::", pickle_path_lasso_lag1)
            output_file = os.path.join(f"s3://{s3_bucketname}/{pickle_path_lasso_lag1}/", f"lasso-t-{i}.joblib")
            print(output_file)
            output_file_temp = f"/tmp/lasso-t-{i}.joblib"
            with fs.open(output_file, 'wb') as f:
                joblib.dump(lasso, f)
            with open(output_file_temp, 'wb') as model_file:
                joblib.dump(lasso, model_file)
            tar_model_path = output_file_temp
            with tarfile.open(tar_model_path, "w:gz") as tar:
                tar.add(output_file_temp, arcname=os.path.basename(output_file_temp))
            # Upload the tar.gz archive to S3
            s3_model_path = f"{pickle_path_lasso_lag1}/lasso-t-{i}.tar.gz"
            s3_client.upload_file(tar_model_path, s3_bucketname, s3_model_path)
            ################
            # Step 5: Evaluate the Model
            y_pred = lasso.predict(X_test_scaled)
            X_pred = lasso.predict(X_train_scaled)
            
            # Step 6: Forecast the next 3 periods and create a consolidated list of predicted values
            n_periods = 3
            forecasts = forecast(data_with_lags, lasso, n_periods)        
            X_prediction=X_pred.tolist()
            test_pred= y_pred.tolist()
            Y_prediction=forecasts
            X_Y_pred=X_prediction+test_pred+Y_prediction
            # Evaluate the model
            metric=pd.DataFrame()
            dates =pd.DataFrame(data['period'])
            new_date = pd.DataFrame({'period': pd.to_datetime(future_dates)})
            dates = pd.concat([dates, new_date], ignore_index=True)
            metric['period']=dates['period']
            qty = pd.DataFrame(data['Total_qty_per_month'])
            new_qty = pd.DataFrame({'Total_qty_per_month': [0,0,0]})
            qty = pd.concat([qty, new_qty], ignore_index=True)
            metric['Actual_values']=qty['Total_qty_per_month']
            metric['Predicted_values_lag1']= pd.DataFrame(X_Y_pred)
            metric['part_number']=i
            final_metric_lag1_lasso=pd.concat([final_metric_lag1_lasso,metric])        
        except Exception as e:
            print(f"{i} part number has error: {e}")
    return final_metric_lag1_lasso

# %%
print(datetime.now())
# Out:
# 2024-11-06 13:04:29.158026

# %%
# final_data_subset

# %%
training_date = pd.to_datetime(config.get_value('model_training_date'))
file_date = training_date.strftime("%Y-%m-%d")

# %%
# final_data_subset = final_data[final_data['part_number'].isin(parts_list[:100])]  # line to be commented post testing
final_data_subset = final_data[final_data['part_number'].isin(parts_list[:])]
prefix_lasso_pickle = f"{config.get_value('primary_path')}/{config.get_value('tpcap_model')}/{config.get_value('model_training_date')}/{'lasso'}"
prefix_output = f"{config.get_value('primary_path')}/{config.get_value('tpcap_model')}/{config.get_value('model_training_date')}/{config.get_value('model_output_folder_name')}"
# print(prefix_output)
# print(prefix_lasso_pickle)
lasso_data = lasso_lag1_func(final_data_subset, bucket, prefix_lasso_pickle, training_end_date)
file_name_train_lasso_prefix = f'{config.get_value("file_name_train_lasso_prefix")}{file_date}.xlsx'
file_path_train_lasso = f's3://{bucket}/{prefix_output}/{file_name_train_lasso_prefix}'
lasso_data.to_excel(file_path_train_lasso, index=False)
# Out:
# PZT0038023
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PZT0038023.joblib
# 473110K010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473110K010.joblib
# 47311KK020
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-47311KK020.joblib
# 90364T0024
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-90364T0024.joblib
# 47313KK030
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-47313KK030.joblib
# 47314KK020
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-47314KK020.joblib
# 473160K030
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473160K030.joblib
# 90364T0028
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-90364T0028.joblib
# 464300K170
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464300K170.joblib
# 47316KK020
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-47316KK020.joblib
# 473170K010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473170K010.joblib
# 47322KK010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-47322KK010.joblib
# 90366T0008
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-90366T0008.joblib
# 473290K011
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473290K011.joblib
# 473290K021
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473290K021.joblib
# 473410K010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473410K010.joblib
# 130410Y04003
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-130410Y04003.joblib
# 47265200501
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-47265200501.joblib
# 90311T0080
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-90311T0080.joblib
# 464300K150
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464300K150.joblib
# 464300K120
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464300K120.joblib
# 462430K010B0
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-462430K010B0.joblib
# 463040K030
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-463040K030.joblib
# 743200K020B0
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-743200K020B0.joblib
# 4640252030
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-4640252030.joblib
# 464100K011
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464100K011.joblib
# 464100K120
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464100K120.joblib
# 4641035420A1
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-4641035420A1.joblib
# 464300K100
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464300K100.joblib
# 4642002310
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-4642002310.joblib
# 4642006070
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-4642006070.joblib
# 464200A020
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464200A020.joblib
# 464200D260
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464200D260.joblib
# 90364T0027
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-90364T0027.joblib
# 464200D270
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464200D270.joblib
# 464200K011
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464200K011.joblib
# 464200K030
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-464200K030.joblib
# 4642004050
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-4642004050.joblib
# 473410K080
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473410K080.joblib
# 473430K080
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473430K080.joblib
# 473210D360
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-473210D360.joblib
# 130410Y04001
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-130410Y04001.joblib
# 472010K040
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-472010K040.joblib
# 4712112020A1
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-4712112020A1.joblib
# 47351KK010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-47351KK010.joblib
# 049450K321
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-049450K321.joblib
# 458970K010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-458970K010.joblib
# 455360K010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-455360K010.joblib
# 452030K040
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-452030K040.joblib
# 044660D040
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-044660D040.joblib
# 452030K010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-452030K010.joblib
# 451870K050C0
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-451870K050C0.joblib
# 4518706050B0
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-4518706050B0.joblib
# 451860K120C0
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-451860K120C0.joblib
# 11201BZ100
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-288000C361.joblib
# 174300T850
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-174300T850.joblib
# 11101B9625
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-11101B9625.joblib
# 61063BZ070
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-61063BZ070.joblib
# 166200Y062
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-166200Y062.joblib
# 55310BZ060C0
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-55310BZ060C0.joblib
# 517950K200
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-517950K200.joblib
# 56117KK041
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-56117KK041.joblib
# 1780152021
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-1780152021.joblib
# 9004A30059
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-9004A30059.joblib
# 135080E011
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-135080E011.joblib
# 52812BZ010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-52812BZ010.joblib
# 65638BZ310
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-65638BZ310.joblib
# 43420BZ260
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-43420BZ260.joblib
# 8110BBZB30
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-8110BBZB30.joblib
# 81156BZB30
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-81156BZB30.joblib
# 53805BZ120
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-53805BZ120.joblib
# 48710BZ480
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-48710BZ480.joblib
# 8110ABZB30
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-8110ABZB30.joblib
# PC1760K01H
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PC1760K01H.joblib
# 88460BZ340
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-88460BZ340.joblib
# 43410BZ250
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-43410BZ250.joblib
# 65637BZ320
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-65637BZ320.joblib
# 73910BZ070
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-73910BZ070.joblib
# 74563YZB25
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-74563YZB25.joblib
# PC507BY00111
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PC507BY00111.joblib
# 811450KU40
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-811450KU40.joblib
# 89070BZ550
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-89070BZ550.joblib
# 48684BZ130
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-48684BZ130.joblib
# 76822BZ080
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-76822BZ080.joblib
# 73920BZ070
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-73920BZ070.joblib
# 81145YP400
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-81145YP400.joblib
# 9094205043
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-9094205043.joblib
# PC3820K01F
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PC3820K01F.joblib
# 85214B2290
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-85214B2290.joblib
# 811100KU30
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-811100KU30.joblib
# 091110K082
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-091110K082.joblib
# 526110D181
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-526110D181.joblib
# 89341BZ200B0
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-89341BZ200B0.joblib
# 53702KK240
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-53702KK240.joblib
# 89994BZ170
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-89994BZ170.joblib
# 8110A02U30
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-8110A02U30.joblib
# 815500K700
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-815500K700.joblib
# 81116BZB30
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-81116BZB30.joblib
# PC3820K01H
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PC3820K01H.joblib
# 81150YP380
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-81150YP380.joblib
# 19114B2060
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-19114B2060.joblib
# 81551BZ490
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-81551BZ490.joblib
# 174300T740
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-174300T740.joblib
# 8110B02U20
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-8110B02U20.joblib
# 87139BZ050
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-87139BZ050.joblib
# 678370K093
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-678370K093.joblib
# 890700KB41
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-890700KB41.joblib
# 61061YY010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-61061YY010.joblib
# 53088YY010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-53088YY010.joblib
# 451000D841C3
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-451000D841C3.joblib
# P41870K007
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-P41870K007.joblib
# 42603VT010
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-42603VT010.joblib
# 90109T0074
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-90109T0074.joblib
# 451000KE51C3
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-451000KE51C3.joblib
# 288000T341
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-288000T341.joblib
# PC6A30K01D
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PC6A30K01D.joblib
# 53112YP590
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-53112YP590.joblib
# 87139EC14552370
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-87139EC14552370.joblib
# 89348VT050A1
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-89348VT050A1.joblib
# 52119YP975
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-52119YP975.joblib
# 521191K902
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-521191K902.joblib
# PS382BY004
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PS382BY004.joblib
# 2880037111
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-2880037111.joblib
# PC55712001
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PC55712001.joblib
# PC1860K1Q3
# path:: persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso
# s3://s3-dx-tdem-ie-nonprod-persist/persist-bo/persist-bo-demand-forecast/tpcap-models/20241106/lasso/lasso-t-PC1860K1Q3.joblib

# %%
end_time = datetime.now()
print("Total time taken for Lasso Training::", (end_time-start_time).seconds/60, " minutes")
# Out:
# Total time taken for Lasso Training:: 15.55  minutes
